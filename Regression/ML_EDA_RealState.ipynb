# %% [markdown]
# <a href="https://colab.research.google.com/github/bobbyknit007/ML/blob/main/Regression/ML_EDA_RealState.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the csv file , understand contents
df=pd.read_csv('/content/Real_Estate.csv')
df.head(5)
# Out:
#              Transaction date  House age  Distance to the nearest MRT station  \
# 0  2012-09-02 16:42:30.519336       13.3                            4082.0150
# 1  2012-09-04 22:52:29.919544       35.5                             274.0144
# 2  2012-09-05 01:10:52.349449        1.1                            1978.6710
# 3  2012-09-05 13:26:01.189083       22.2                            1055.0670
# 4  2012-09-06 08:29:47.910523        8.5                             967.4000
#
#    Number of convenience stores   Latitude   Longitude  \
# 0                             8  25.007059  121.561694
# 1                             2  25.012148  121.546990
# 2                            10  25.003850  121.528336
# 3                             5  24.962887  121.482178
# 4                             6  25.011037  121.479946
#
#    House price of unit area
# 0                  6.488673
# 1                 24.970725
# 2                 26.694267
# 3                 38.091638
# ...

# %%
print('Data Set has rows {}, columns {}'.format( df.shape[0], df.shape[1]))
print('Data set has columns {}'.format(df.columns.values))
print('Data set does not have missing or null values')
# Out:
# Data Set has rows 414, columns 7
# Data set has columns ['Transaction date' 'House age' 'Distance to the nearest MRT station'
#  'Number of convenience stores' 'Latitude' 'Longitude'
#  'House price of unit area']
# Data set does not have missing or null values

# %%
df.isnull().sum()
# Out:
# Transaction date                       0
# House age                              0
# Distance to the nearest MRT station    0
# Number of convenience stores           0
# Latitude                               0
# Longitude                              0
# House price of unit area               0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Transaction date                       0
# House age                              0
# Distance to the nearest MRT station    0
# Number of convenience stores           0
# Latitude                               0
# Longitude                              0
# House price of unit area               0
# dtype: int64

# %%
#Look for duplicates value
df.duplicated().sum()
#df[df.duplicated()==True]
#Remove
#df=df.drop_duplicates()
# Out:
# 0

# %%
df.duplicated().sum()
print('Data Set has rows {}, columns {}'.format( df.shape[0], df.shape[1]))
# Out:
# Data Set has rows 414, columns 7

# %%
#Look for unique values in each column
for col in df.columns:
  print('Column {} has {} unique values'.format(col,df[col].nunique()))
# Out:
# Column Transaction date has 414 unique values
# Column House age has 178 unique values
# Column Distance to the nearest MRT station has 183 unique values
# Column Number of convenience stores has 11 unique values
# Column Latitude has 414 unique values
# Column Longitude has 414 unique values
# Column House price of unit area has 384 unique values

# %%
sns.scatterplot(data=df, x='House age', y='House price of unit area')
# Out:
# <Axes: xlabel='House age', ylabel='House price of unit area'>

# %%
sns.scatterplot(data=df, x='Distance to the nearest MRT station', y='House price of unit area')
# Out:
# <Axes: xlabel='Distance to the nearest MRT station', ylabel='House price of unit area'>

# %%
sns.scatterplot(data=df, x='Number of convenience stores', y='House price of unit area')
# Out:
# <Axes: xlabel='Number of convenience stores', ylabel='House price of unit area'>

# %%
sns.scatterplot(data=df, x='Latitude', y='House price of unit area')
# Out:
# <Axes: xlabel='Latitude', ylabel='House price of unit area'>

# %%
#Look for unique values in each column
for col in df.columns:
  print('Column {} has {} unique values'.format(col,df[col].nunique()))
# Out:
# Column Transaction date has 414 unique values
# Column House age has 178 unique values
# Column Distance to the nearest MRT station has 183 unique values
# Column Number of convenience stores has 11 unique values
# Column Latitude has 414 unique values
# Column Longitude has 414 unique values
# Column House price of unit area has 384 unique values

# %%
corr = df[['Latitude','Longitude','House age','Distance to the nearest MRT station','Number of convenience stores','House price of unit area']].corr()
sns.heatmap(corr, annot=True)
plt.show()
