# %% [markdown]
# <a href="https://colab.research.google.com/github/dhsingh0815/ML/blob/main/Theory_PCA_DimensionaltyCurse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Curse of Dimensionalty
#
# Feature Selection - PCA  Prinicipal Component Ananlysis
# Feature Extraction

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here we had 2 features Size and No of rooms . we have to choose one of them with highest variance , we will use PCA
# First convert 2 D space to 1 D space
# 2D space - means both features are there

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Relation between Matrix Product and Dot Product
# A and B are vecctors. </br>
# A.B (dot product)is a scalar value = AT(Transpose of A) B (matrix multiplication) </br>
# A = a1i+a2j+a3k </br>
# B = b1i+b2j+b3k </br>
# A and B in matrix form are 3X1 matrix .  </br>
# A =[1     B=[1 </br>
#     2        2  </br>
#     3        3 </br>
#    ]        ] </br>
# Matrix Multiplication ATB (1X3 3X1) will result in single value 1X1 </br>
# [1 2 3][1   </br>
#         2    </br>
#         3   </br>
#         ]    </br>
# =[1+4+9]= 14 </br>
# Dot Product A.B </br>
# 1*1 + 2*2 + 3*3 = 1+4+9 = 14 </br>

# %% [markdown]
# https://www.youtube.com/watch?v=FD4DeN81ODY PCA Visual  </br>
# https://www.youtube.com/watch?v=osgqQy9Hr8s PCA Concept/Python
