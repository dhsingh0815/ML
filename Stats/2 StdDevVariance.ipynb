# %% [markdown]
# # Standard Deviation and Variance

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes1 = np.random.normal(100.0, 50.0, 10000)
incomes2 = np.random.normal(100.0, 25.0, 10000)
incomes3 = np.random.normal(100.0, 15.0, 10000)
incomes4 = np.random.normal(100.0, 10.0, 10000)
incomes5 = np.random.normal(100.0, 5.0, 10000)
incomes6 = np.random.normal(100.0, 70.0, 10000)
plt.hist(incomes1, 50,)
plt.legend([incomes1.std()])
plt.figure()

plt.hist(incomes2, 50)
plt.legend([incomes2.std()])
plt.figure()

plt.hist(incomes3, 50)
plt.legend([incomes3.std()])
plt.figure()

plt.hist(incomes4, 50)
plt.legend([incomes4.std()])
plt.figure()

plt.hist(incomes5, 50)
plt.legend([incomes5.std()])
plt.figure()

plt.hist(incomes6, 50)
plt.legend([incomes6.std()])
plt.figure()

plt.show()

# %%
incomes.std()
# Out:
# 49.95328217456521

# %%
incomes.var()
# Out:
# 2477.9005223471163

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters on the normal function, and see what effect it has on the shape of the distribution. How does that new shape relate to the standard deviation and variance?
