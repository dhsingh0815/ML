# %% [markdown]
# # Examples of Data Distributions

# %% [markdown]
# ## Uniform Distribution

# %%
# %matplotlib inline
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

values = np.random.uniform(-10.0, 10.0, 100000)
plt.hist(values, 10000)
plt.legend([np.mean(values)])
plt.figure()
plt.plot(values, norm.pdf(values))
plt.legend([np.std(values)])
plt.figure()
plt.show()

# %% [markdown]
# ## Normal / Gaussian

# %% [markdown]
# Visualize the probability density function:

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt

axes= plt.axes()
axes.set_xlim([-4,4])
a = np.arange(-3, 3, 0.0000001)
plt.plot(a, norm.pdf(a,2),'c')

#plt.figure()
''''''
x = np.arange(-3, 3, 0.00001)# 0.001 is the increment . If increment reduces, then the curve will get rougher.
# arange method gives evenly spaced elements
#plt.hist(x, 10000)
#plt.legend([np.mean(x)])
#plt.figure()
#plt.plot(x, norm.pdf(x))
#plt.legend([np.std(x)])
#plt.figure()

plt.plot(x, norm.pdf(x,1),'b')

#plt.figure()
y = np.arange(-3, 3, 0.001)
plt.plot(y, norm.pdf(y,0),'r')

#plt.figure()
z = np.arange(-3, 3, 0.1)
plt.plot(z, norm.pdf(z,-1),'g')

plt.legend(['10e-7','10e-5','10e-3','10e-1'],loc='upper left')
plt.grid()
#plt.figure()


plt.savefig('C:\\Users\\Admin\\Downloads\\PDfwithStepSziedata.png',
        bbox_inches='tight',
        pad_inches=1,
        transparent=True,
        facecolor='w',
        edgecolor='w',
        orientation='Portrait')
plt.show()

# %% [markdown]
# Generate some random numbers with a normal distribution. "mu" is the desired mean, "sigma" is the standard deviation:

# %%
import numpy as np
import matplotlib.pyplot as plt

mu = 5.0
sigma = 2.0
values = np.random.normal(mu, sigma, 10000)
plt.hist(values, 50)
plt.show()

# %% [markdown]
# ## Exponential PDF / "Power Law"

# %%
from scipy.stats import expon
import matplotlib.pyplot as plt

x = np.arange(0, 10, 0.001)
plt.plot(x, expon.pdf(x))

# %% [markdown]
# ## Binomial Probability Mass Function

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt

n, p = 10, 0.1
x = np.arange(0, 10, 0.001)
plt.plot(x, binom.pmf(x, n, p))

# %% [markdown]
# ## Poisson Probability Mass Function

# %% [markdown]
# Example: My website gets on average 500 visits per day. What's the odds of getting 550?

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt

mu = 500
x = np.arange(400, 600, 0.5)
plt.plot(x, poisson.pmf(x, mu))

# %% [markdown]
# ## Quiz!

# %% [markdown]
# What's the equivalent of a probability distribution function when using discrete instead of continuous data?
