# %% [markdown]
# <a href="https://colab.research.google.com/github/dhsingh0815/ML/blob/main/Classifier/Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# Creating Empty DataFrame and Storing it in variable df
df = pd.DataFrame()

# Printing Empty DataFrame

df['id']=[0,1,2,3,4,5]
df['x0']=[4.3, 6.5, 2.7, 6.6, 6.5 , 2.7]
df['x1']=[4.9, 6.1, 4.8, 4.4, 2.9 , 6.7]
df['x2']=[4.1, 5.9, 4.1, 4.5, 4.7 , 4.2]
df['x3']=[6.7, 5.5, 5.0, 3.9, 4.6, 5.3]
df['x4']=[5.5, 5.9, 5.6, 5.9, 6.1, 5.8]
df['x5']=[0, 0, 0, 1, 1, 1]
print(df)
# Out:
#    id   x0   x1   x2   x3   x4  x5
# 0   0  4.3  4.9  4.1  6.7  5.5   0
# 1   1  6.5  6.1  5.9  5.5  5.9   0
# 2   2  2.7  4.8  4.1  5.0  5.6   0
# 3   3  6.6  4.4  4.5  3.9  5.9   1
# 4   4  6.5  2.9  4.7  4.6  6.1   1
# 5   5  2.7  6.7  4.2  5.3  5.8   1
