# %% [markdown]
# <a href="https://colab.research.google.com/github/bobbyknit007/ML/blob/main/Classifier/DecisionTree_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ![DecisionTree.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
