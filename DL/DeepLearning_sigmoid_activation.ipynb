# %% [markdown]
# <a href="https://colab.research.google.com/github/dhsingh0815/ML/blob/main/DL/DeepLearning_sigmoid_activation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install tensorflow matplotlib

# %%
# Import required libraries
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %%
# 1. Generate synthetic data
np.random.seed(42)  # reproducibility
X = np.random.rand(1000, 2)  # 1000 samples, 2 features each
y = (X[:, 0] + X[:, 1] > 1).astype(int)  # Label: 1 if sum > 1 else 0

# %% [markdown]
# X - is a 1000X2 matrix.
# X[:,0] is a column matrix out of 0th column, X[:,1] is again column matrix out of 1st column.
# X[:, 0] + X[:, 1] - Matrix addition.
# X[:, 0] + X[:, 1] > 1 - Each element of 1000X1 matrix is compared with 1, it will result in a 1000X1 matrix with values being true/false.
# astype(int) - converts true/false to 1/0.
# y is essentially a 1000X1 matrix with values 1 or 0

# %%
# 2. Visualize the data
plt.figure(figsize=(6,6))
plt.scatter(X[y==0][:,0], X[y==0][:,1], color='blue', label='Class 0')
plt.scatter(X[y==1][:,0], X[y==1][:,1], color='red', label='Class 1')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Input Data and Labels')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Couldn't understand X[y==0][:,0]?

# %%
# 3. Build a simple neural network model
model = keras.Sequential([
    layers.Dense(4, activation='sigmoid', input_shape=(2,)),  # hidden layer
    # A layer with 4 Neurons , activation function is relu ,
    layers.Dense(1, activation='sigmoid')  # output layer for binary classification, 1 neuron, activation function sigmoid
])

# 4. Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ABove model has 2 layers, 1 st layer has 4 neurons, activation func relu.
# 2nd layer output layer has 1 neuron, activation func sigmoid to have binary output. **What is this input_shape???**
# Loss fun is binary cross entropy , optimizer is Adam is Adaptive learning rate optimization algo , it updates weights for each parameter individually.
# To evaluate models efficiency, metric 'accuracy' is employed.

# %%
# 5. Train the model
history = model.fit(X, y, epochs=50, batch_size=32, verbose=1)

# 6. Plot training loss and accuracy
plt.figure(figsize=(12,5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='purple')
plt.title("Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Binary Crossentropy Loss")
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='green')
plt.title("Accuracy over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1211 - loss: 0.7107
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1075 - loss: 0.7093
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1157 - loss: 0.7066
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2026 - loss: 0.7049
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4104 - loss: 0.7015
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3390 - loss: 0.7005
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4278 - loss: 0.6986
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5011 - loss: 0.6962
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4924 - loss: 0.6945
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4948 - loss: 0.6927
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4964 - loss: 0.6908
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5001 - loss: 0.6886
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5146 - loss: 0.6855
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5160 - loss: 0.6839
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5197 - loss: 0.6828
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5534 - loss: 0.6802
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5874 - loss: 0.6790
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6223 - loss: 0.6765
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6282 - loss: 0.6760
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6500 - loss: 0.6730
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6164 - loss: 0.6716
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6349 - loss: 0.6713
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6705 - loss: 0.6649
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6381 - loss: 0.6639
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7094 - loss: 0.6586
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7084 - loss: 0.6602
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7701 - loss: 0.6543
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7814 - loss: 0.6483
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7909 - loss: 0.6472
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8229 - loss: 0.6475
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8288 - loss: 0.6417
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8169 - loss: 0.6383
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8329 - loss: 0.6358
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8313 - loss: 0.6317
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8292 - loss: 0.6282
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8474 - loss: 0.6254
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8570 - loss: 0.6188
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8736 - loss: 0.6110
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8737 - loss: 0.6106
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8844 - loss: 0.6074
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8981 - loss: 0.5997
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8987 - loss: 0.5953
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8910 - loss: 0.5880
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9009 - loss: 0.5851
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9109 - loss: 0.5769
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8918 - loss: 0.5778
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9074 - loss: 0.5663
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9082 - loss: 0.5653
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9072 - loss: 0.5624
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9076 - loss: 0.5612

# %% [markdown]
# Model is trained with training data , we have 1000 data points but here we are training with 32 datapoints at a time. For each data point, there will be 50 epoch. Verbose - level of output info generated for user

# %%
# 7. Test a few predictions
test_samples = np.array([[0.1, 0.2], [0.6, 0.6], [0.4, 0.3], [0.8, 0.5]])
predictions = model.predict(test_samples)
print("Input\t\tPredicted Probability\tClass")
for i, pred in enumerate(predictions):
    #print(pred)
    print(f"{test_samples[i]}\t{pred[0]:.4f}\t\t\t{int(pred[0] > 0.5)}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Input		Predicted Probability	Class
# [0.1 0.2]	0.3410			0
# [0.6 0.6]	0.5695			1
# [0.4 0.3]	0.4452			0
# [0.8 0.5]	0.5925			1

# %% [markdown]
# Predicted Probability - Probability of what?

# %%
# 8. Plotting the decision boundary
# Create a grid of points in the 2D input space
xx, yy = np.meshgrid(np.linspace(0, 1, 200), np.linspace(0, 1, 200))
grid = np.c_[xx.ravel(), yy.ravel()]

# Predict on the entire grid
probs = model.predict(grid).reshape(xx.shape)

# Plot the decision boundary
plt.figure(figsize=(7,7))
plt.contourf(xx, yy, probs, levels=[0, 0.5, 1], cmap='RdBu', alpha=0.6)
plt.scatter(X[y==0][:,0], X[y==0][:,1], color='blue', label='Class 0', edgecolor='k')
plt.scatter(X[y==1][:,0], X[y==1][:,1], color='red', label='Class 1', edgecolor='k')
plt.title("Decision Boundary Learned by Neural Network")
plt.xlabel("x1")
plt.ylabel("x2")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %% [markdown]
# np.linspace(0, 1, 200) - create 200 numbers between 0 and 1
# np.meshgrid - creates 2 D array from input two 1-D arrays
# ravel - flattens the array
# np.c_ concatenates the array

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['accuracy'], label='Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.title('Training Progress')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# sigmoid being a sort of binary func , seems does early one sided decisions and hence overall goes more wrong.
