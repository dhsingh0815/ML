# %% [markdown]
# <a href="https://colab.research.google.com/github/dhsingh0815/ML/blob/main/DL/DeepLearning_linear_activation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install tensorflow matplotlib

# %%
# Import required libraries
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %%
# 1. Generate synthetic data
np.random.seed(42)  # reproducibility
X = np.random.rand(1000, 2)  # 1000 samples, 2 features each
y = (X[:, 0] + X[:, 1] > 1).astype(int)  # Label: 1 if sum > 1 else 0

# %% [markdown]
# X - is a 1000X2 matrix.
# X[:,0] is a column matrix out of 0th column, X[:,1] is again column matrix out of 1st column.
# X[:, 0] + X[:, 1] - Matrix addition.
# X[:, 0] + X[:, 1] > 1 - Each element of 1000X1 matrix is compared with 1, it will result in a 1000X1 matrix with values being true/false.
# astype(int) - converts true/false to 1/0.
# y is essentially a 1000X1 matrix with values 1 or 0

# %%
# 2. Visualize the data
plt.figure(figsize=(6,6))
plt.scatter(X[y==0][:,0], X[y==0][:,1], color='blue', label='Class 0')
plt.scatter(X[y==1][:,0], X[y==1][:,1], color='red', label='Class 1')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Input Data and Labels')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Couldn't understand X[y==0][:,0]?

# %%
# 3. Build a simple neural network model
model = keras.Sequential([
    layers.Dense(4, activation='linear', input_shape=(2,)),  # hidden layer
    # A layer with 4 Neurons , activation function is relu ,
    layers.Dense(1, activation='sigmoid')  # output layer for binary classification, 1 neuron, activation function sigmoid
])

# 4. Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ABove model has 2 layers, 1 st layer has 4 neurons, activation func relu.
# 2nd layer output layer has 1 neuron, activation func sigmoid to have binary output. **What is this input_shape???**
# Loss fun is binary cross entropy , optimizer is Adam is Adaptive learning rate optimization algo , it updates weights for each parameter individually.
# To evaluate models efficiency, metric 'accuracy' is employed.

# %%
# 5. Train the model
history = model.fit(X, y, epochs=50, batch_size=32, verbose=1)

# 6. Plot training loss and accuracy
plt.figure(figsize=(12,5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='purple')
plt.title("Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Binary Crossentropy Loss")
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='green')
plt.title("Accuracy over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5230 - loss: 0.7604
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4854 - loss: 0.7489
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4054 - loss: 0.7419
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3609 - loss: 0.7315
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2734 - loss: 0.7207
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1428 - loss: 0.7169
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2172 - loss: 0.7104
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4215 - loss: 0.7043
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4934 - loss: 0.6988
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5082 - loss: 0.6919
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4778 - loss: 0.6896
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5068 - loss: 0.6770
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5168 - loss: 0.6681
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5090 - loss: 0.6662
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5639 - loss: 0.6543
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5900 - loss: 0.6433
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6133 - loss: 0.6339
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6445 - loss: 0.6264
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6565 - loss: 0.6168
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6871 - loss: 0.6059
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7307 - loss: 0.5900
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7442 - loss: 0.5797
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7664 - loss: 0.5627
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7861 - loss: 0.5477
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7952 - loss: 0.5383
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8128 - loss: 0.5257
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8295 - loss: 0.5136
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8382 - loss: 0.5077
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8399 - loss: 0.4956
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8531 - loss: 0.4847
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8786 - loss: 0.4589
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8857 - loss: 0.4491
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8984 - loss: 0.4420
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8968 - loss: 0.4273
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9055 - loss: 0.4175
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9038 - loss: 0.4009
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9188 - loss: 0.3935
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9200 - loss: 0.3790
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9406 - loss: 0.3753
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9387 - loss: 0.3598
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9328 - loss: 0.3566
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9279 - loss: 0.3524
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9463 - loss: 0.3362
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9342 - loss: 0.3366
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9489 - loss: 0.3130
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9557 - loss: 0.3133
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9409 - loss: 0.3116
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9522 - loss: 0.3044
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9654 - loss: 0.2951
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9602 - loss: 0.2832

# %% [markdown]
# Model is trained with training data , we have 1000 data points but here we are training with 32 datapoints at a time. For each data point, there will be 50 epoch. Verbose - level of output info generated for user

# %%
# 7. Test a few predictions
test_samples = np.array([[0.1, 0.2], [0.6, 0.6], [0.4, 0.3], [0.8, 0.5]])
predictions = model.predict(test_samples)
print("Input\t\tPredicted Probability\tClass")
for i, pred in enumerate(predictions):
    #print(pred)
    print(f"{test_samples[i]}\t{pred[0]:.4f}\t\t\t{int(pred[0] > 0.5)}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Input		Predicted Probability	Class
# [0.1 0.2]	0.0494			0
# [0.6 0.6]	0.7379			1
# [0.4 0.3]	0.2389			0
# [0.8 0.5]	0.8209			1

# %% [markdown]
# Predicted Probability - Probability of what?

# %%
# 8. Plotting the decision boundary
# Create a grid of points in the 2D input space
xx, yy = np.meshgrid(np.linspace(0, 1, 200), np.linspace(0, 1, 200))
grid = np.c_[xx.ravel(), yy.ravel()]

# Predict on the entire grid
probs = model.predict(grid).reshape(xx.shape)

# Plot the decision boundary
plt.figure(figsize=(7,7))
plt.contourf(xx, yy, probs, levels=[0, 0.5, 1], cmap='RdBu', alpha=0.6)
plt.scatter(X[y==0][:,0], X[y==0][:,1], color='blue', label='Class 0', edgecolor='k')
plt.scatter(X[y==1][:,0], X[y==1][:,1], color='red', label='Class 1', edgecolor='k')
plt.title("Decision Boundary Learned by Neural Network")
plt.xlabel("x1")
plt.ylabel("x2")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %% [markdown]
# np.linspace(0, 1, 200) - create 200 numbers between 0 and 1
# np.meshgrid - creates 2 D array from input two 1-D arrays
# ravel - flattens the array
# np.c_ concatenates the array

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['accuracy'], label='Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.title('Training Progress')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# I thought 'linear' activation func won't work better but turns out it looks doing better , and reasoning seems is that the problem is not actually a linear problem.
