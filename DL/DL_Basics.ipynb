# %% [markdown]
# <a href="https://colab.research.google.com/github/dhsingh0815/ML/blob/main/DL/DL_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![DeepLearningOverview.jpeg](data:image/jpeg;base64,...)![ForwardPropagation.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Gradient _DescendentOverview.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Gradient _DescendentInAction.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![FindingBiasIterativeStepSzie2.png](data:image/png;base64,...)![ANNRNNCNN.png](data:image/png;base64,...)![TensorCodeThought.png](data:image/png;base64,...)
