# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Data/adult.csv')
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 52

# %%
df[df.duplicated()==True]
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 864     24           Private  194630     Bachelors               13
# 11189   37           Private   52870     Bachelors               13
# 11212   29           Private   36440     Bachelors               13
# 13848   30           Private  180317     Assoc-voc               11
# 15960   18      Self-emp-inc  378036          12th                8
# 18476   39           Private  184659       HS-grad                9
# 19399   19           Private  130431       5th-6th                3
# 19726   41           Private  116391     Bachelors               13
# 20606   25           Private  308144     Bachelors               13
# 21162   25           Private  308144     Bachelors               13
# 21385   90           Private   52386  Some-college               10
# 24361   21           Private  243368     Preschool                1
# 25189   29                 ?   41281     Bachelors               13
# ...

# %%
df.drop_duplicates()
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
# capital-gain, capital-loss, hours-per-week has outliers, possibly fnlwgt has out

# %%
#Perform Data Cleaning [ Replace  '?'  With NaN ]
df.replace('?','Nan', inplace=True)
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           Nan  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
#Drop The Column educational-num,capital-gain,capital-loss
df.drop(['educational-num','capital-gain','capital-loss'], axis=1, inplace=True)
df.head()
# Out:
#    age  workclass  fnlwgt     education      marital-status  \
# 0   25    Private  226802          11th       Never-married
# 1   38    Private   89814       HS-grad  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3   44    Private  160323  Some-college  Married-civ-spouse
# 4   18        Nan  103497  Some-college       Never-married
#
#           occupation relationship   race  gender  hours-per-week  \
# 0  Machine-op-inspct    Own-child  Black    Male              40
# 1    Farming-fishing      Husband  White    Male              50
# 2    Protective-serv      Husband  White    Male              40
# 3  Machine-op-inspct      Husband  Black    Male              40
# 4                Nan    Own-child  White  Female              30
#
#   native-country income
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States   >50K
# 3  United-States   >50K
# 4  United-States  <=50K

# %%
#Find the most common education level
df['education'].value_counts().idxmax()# returns the index label of max value
# Out:
# 'HS-grad'

# %%
#find Average hours worked for ">50K" income
df[df['income']=='>50K']['hours-per-week'].mean()
# Out:
# 45.45289638059382

# %%
#Percentage of females in "Machine-op-inspct" occupation
#df[df['occupation']=='Machine-op-inspct']
female_occu=df[df['gender']=='Female']['occupation'].value_counts()
per=(female_occu['Machine-op-inspct']/female_occu.values.sum())*100
print('{} percent females work as machine-op-inspct'.format(per))
# Out:
# 4.965415019762846 percent females work as machine-op-inspct

# %%
#find out the avg age for each occupation
df.groupby('occupation').apply(lambda se : se['age'].mean())
# Out:
# occupation
# Adm-clerical         37.193014
# Armed-Forces         31.466667
# Craft-repair         39.008671
# Exec-managerial      42.198488
# Farming-fishing      41.280537
# Handlers-cleaners    32.654440
# Machine-op-inspct    37.736267
# Nan                  40.069064
# Other-service        35.108674
# Priv-house-serv      43.400826
# Prof-specialty       40.559786
# Protective-serv      38.899288
# Sales                37.408612
# Tech-support         37.150069
# Transport-moving     40.651380
# dtype: float64

# %%
#find out Most common race among "Never-married"

df[df['marital-status']=='Never-married']['race'].value_counts().sort_values(ascending=False).index[0]
# Out:
# 'White'

# %%
#Percentage of people with a college degree or higher
edu_list=['Some-college','Bachelors','Masters','Doctorate']
edu_series =df.groupby('education')['education'].apply(lambda a :a).value_counts()
edu_degree = edu_series[edu_series.index.isin(edu_list)]
total=edu_series.values.sum()
print('Percentage of people with a college degree or higher {}'.format((edu_degree/total*100).sum()))
# Out:
# Percentage of people with a college degree or higher 45.35850292780803

# %%
#Find the employee with the highest fnlwgt
#What is the standard deviation of "age"?
df.head()
# Out:
#    age  workclass  fnlwgt     education      marital-status  \
# 0   25    Private  226802          11th       Never-married
# 1   38    Private   89814       HS-grad  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3   44    Private  160323  Some-college  Married-civ-spouse
# 4   18        Nan  103497  Some-college       Never-married
#
#           occupation relationship   race  gender  hours-per-week  \
# 0  Machine-op-inspct    Own-child  Black    Male              40
# 1    Farming-fishing      Husband  White    Male              50
# 2    Protective-serv      Husband  White    Male              40
# 3  Machine-op-inspct      Husband  Black    Male              40
# 4                Nan    Own-child  White  Female              30
#
#   native-country income
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States   >50K
# 3  United-States   >50K
# 4  United-States  <=50K

# %%
# Out:
# 45.35850292780803
